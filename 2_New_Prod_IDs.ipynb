# %%
import numpy as np
import pandas as pd
import random

from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import KNNBasic
from surprise import KNNWithZScore
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate

from surprise.model_selection import GridSearchCV

from sklearn import preprocessing

# %%
# Reading the data sets into data frames
train_data = pd.read_csv('./Files_Folder/train_data.csv')
test_data = pd.read_csv('./Files_Folder/test_data.csv')
test_data_sub = pd.read_csv('./Files_Folder/test_data_sub.csv')
hold_data = pd.read_csv('./Files_Folder/hold_data.csv')
hold_data_sub = pd.read_csv('./Files_Folder/hold_data_sub.csv')

# %%
print ("train shape = ", train_data.shape)
print ("test shape = ", test_data.shape)
print ("test shape (No Purchase column) = ", test_data_sub.shape)
print ("holdout shape = ", hold_data.shape)
print ("holdout shape (No Purchase column) = ", hold_data_sub.shape)
# Out:
# train shape =  (495062, 12)
# test shape =  (27503, 12)
# test shape (No Purchase column) =  (27503, 11)
# holdout shape =  (27503, 12)
# holdout shape (No Purchase column) =  (27503, 11)

# %%
train_data.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
train_data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  4.950620e+05  495062.000000   495062.000000       495062.000000
# mean   1.003027e+06       8.076748        0.409710            5.401764
# std    1.727099e+03       6.523106        0.491781            3.935342
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001514e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004473e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       338906.000000       150075.000000  495062.000000
# mean             9.844337           12.671438    9265.688885
# std              5.087848            4.124031    5023.842930
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8048.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
# Checking out features that have missing values for the train data set
train_data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            156156
# Product_Category_3            344987
# Purchase                           0
# dtype: int64

# %%
# Checking out the statistical description of numeric features for the test data set
test_data_sub.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  2.750300e+04  27503.000000    27503.000000        27503.000000
# mean   1.003045e+06      8.077592        0.409410            5.414500
# std    1.728325e+03      6.509187        0.491734            3.931152
# min    1.000001e+06      0.000000        0.000000            1.000000
# 25%    1.001548e+06      2.000000        0.000000            1.000000
# 50%    1.003103e+06      7.000000        0.000000            5.000000
# 75%    1.004506e+06     14.000000        1.000000            8.000000
# max    1.006040e+06     20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3
# count        18780.000000         8352.000000
# mean             9.811022           12.617816
# std              5.084547            4.147387
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# 75%             15.000000           16.000000
# max             18.000000           18.000000

# %%
# Checking out the features that have missing values in the test data set
test_data_sub.isnull().sum()
# Out:
# User_ID                           0
# Product_ID                        0
# Gender                            0
# Age                               0
# Occupation                        0
# City_Category                     0
# Stay_In_Current_City_Years        0
# Marital_Status                    0
# Product_Category_1                0
# Product_Category_2             8723
# Product_Category_3            19151
# dtype: int64

# %%
hold_data_sub.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  2.750300e+04  27503.000000    27503.000000        27503.000000
# mean   1.003047e+06      8.075083        0.408864            5.439152
# std    1.735572e+03      6.528340        0.491633            3.956815
# min    1.000001e+06      0.000000        0.000000            1.000000
# 25%    1.001532e+06      2.000000        0.000000            1.000000
# 50%    1.003081e+06      7.000000        0.000000            5.000000
# 75%    1.004510e+06     14.000000        1.000000            8.000000
# max    1.006040e+06     20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3
# count        18744.000000         8394.000000
# mean             9.837388           12.661306
# std              5.066007            4.126847
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# 75%             15.000000           16.000000
# max             18.000000           18.000000

# %%
# Checking out the features that have missing values in the hold out data set
hold_data_sub.isnull().sum()
# Out:
# User_ID                           0
# Product_ID                        0
# Gender                            0
# Age                               0
# Occupation                        0
# City_Category                     0
# Stay_In_Current_City_Years        0
# Marital_Status                    0
# Product_Category_1                0
# Product_Category_2             8759
# Product_Category_3            19109
# dtype: int64

# %%
# Filling missing values with place holders
train_data.Product_Category_2.fillna('BB', inplace = True)
train_data.Product_Category_3.fillna('CC', inplace = True)
test_data_sub.Product_Category_2.fillna('BB', inplace = True)
test_data_sub.Product_Category_3.fillna('CC', inplace = True)
hold_data_sub.Product_Category_2.fillna('BB', inplace = True)
hold_data_sub.Product_Category_3.fillna('CC', inplace = True)

train_data.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
test_data_sub.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# dtype: int64

# %%
hold_data_sub.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# dtype: int64

# %%
# Checking the number of unique Product_IDs in the test, train & hold out data sets
train_Prod_IDs = list(set(train_data.Product_ID))
test_Prod_IDs = list(set(test_data_sub.Product_ID))
hold_Prod_IDs = list(set(hold_data_sub.Product_ID))
print (len(train_Prod_IDs))
print (len(test_Prod_IDs))
print (len(hold_Prod_IDs))
# Out:
# 3615
# 2819
# 2824

# %%
nid = test_Prod_IDs
print ('length of test_IDs = ', len (nid))

nid.extend(hold_Prod_IDs)
print ('length of test_IDs & holdout_IDs = ', len(nid))

nid = set(nid)
print ('length of unique test_IDs & holdout_IDs = ', len(nid) )
# Out:
# length of test_IDs =  2819
# length of test_IDs & holdout_IDs =  5643
# length of unique test_IDs & holdout_IDs =  3122

# %%
New_Prod_IDs = []
for i in nid:
    if i not in train_Prod_IDs:
        New_Prod_IDs.append(i)

# %%
print (len(New_Prod_IDs))
New_Prod_IDs
# Out:
# 16
# ['P00152842',
#  'P00022042',
#  'P00063742',
#  'P00306942',
#  'P00300742',
#  'P00012342',
#  'P00068742',
#  'P00065942',
#  'P00325342',
#  'P00301942',
#  'P00069742',
#  'P00171142',
#  'P00169842',
#  'P00315142',
#  'P00239442',
#  'P00150242']

# %%
# Putting test and hold in a single dataframe
print (test_data_sub.shape)
print (hold_data_sub.shape)
frames = [test_data_sub, hold_data_sub]
test_hold_data_sub = pd.concat(frames)
print (test_hold_data_sub.shape)
# Out:
# (27503, 11)
# (27503, 11)
# (55006, 11)

# %%
# Getting the summary of the products in train data set that has the same product categories as 
# the new products in test data sets.
# New products in test data sets are products that were not in the train data sets but are found in
# test data sets

agg_mean = []
agg_median = []
agg_std = []
agg_count = []
agg_min = []
agg_max = []
agg_25 = []
agg_75 = []

for i in New_Prod_IDs:
    
    a = test_hold_data_sub[test_hold_data_sub.Product_ID == i].iloc[0]
    agg_mean.append(train_data[(train_data.Product_Category_1 == a.Product_Category_1) & (train_data.Product_Category_2 == a.Product_Category_2) & (train_data.Product_Category_3 == a.Product_Category_3)].describe().Purchase['mean'])
    agg_median.append(train_data[(train_data.Product_Category_1 == a.Product_Category_1) & (train_data.Product_Category_2 == a.Product_Category_2) & (train_data.Product_Category_3 == a.Product_Category_3)].describe().Purchase['50%'])
    agg_std.append(train_data[(train_data.Product_Category_1 == a.Product_Category_1) & (train_data.Product_Category_2 == a.Product_Category_2) & (train_data.Product_Category_3 == a.Product_Category_3)].describe().Purchase['std'])
    agg_count.append(train_data[(train_data.Product_Category_1 == a.Product_Category_1) & (train_data.Product_Category_2 == a.Product_Category_2) & (train_data.Product_Category_3 == a.Product_Category_3)].describe().Purchase['count'])
    agg_min.append(train_data[(train_data.Product_Category_1 == a.Product_Category_1) & (train_data.Product_Category_2 == a.Product_Category_2) & (train_data.Product_Category_3 == a.Product_Category_3)].describe().Purchase['min'])
    agg_max.append(train_data[(train_data.Product_Category_1 == a.Product_Category_1) & (train_data.Product_Category_2 == a.Product_Category_2) & (train_data.Product_Category_3 == a.Product_Category_3)].describe().Purchase['max'])
    agg_25.append(train_data[(train_data.Product_Category_1 == a.Product_Category_1) & (train_data.Product_Category_2 == a.Product_Category_2) & (train_data.Product_Category_3 == a.Product_Category_3)].describe().Purchase['25%'])
    agg_75.append(train_data[(train_data.Product_Category_1 == a.Product_Category_1) & (train_data.Product_Category_2 == a.Product_Category_2) & (train_data.Product_Category_3 == a.Product_Category_3)].describe().Purchase['75%'])

# %%
agg_dic = {'Product_ID':New_Prod_IDs, 'mean': agg_mean, '50%': agg_median, 'std': agg_std, 'count':agg_count, 'min':agg_min, 'max':agg_max, '25%': agg_25, '75%': agg_75}

# %%
# Storing the details of similar products in a csv file
# This can be used as a look up table during the analysis.
# The Product_ID are products that are in the test data set but not in the train data set
# The other parameters like mean, 50% etc are the summary of purchases of similar products 
# found in the train data set
New_Product = pd.DataFrame (agg_dic)
New_Product.head()
# Out:
#   Product_ID          mean      50%          std    count     min      max  \
# 0  P00152842   7511.514088   7908.0  1990.488557  54586.0  1939.0  10082.0
# 1  P00022042  14777.288566  16294.0  4343.472147   8816.0  4036.0  20971.0
# 2  P00063742   7511.514088   7908.0  1990.488557  54586.0  1939.0  10082.0
# 3  P00306942   4677.189748   4609.0  1877.310300  11120.0  1472.0   7654.0
# 4  P00300742   6101.874236   6886.0  1960.053653  57290.0  1713.0   8907.0
#
#        25%      75%
# 0   6047.0   9715.0
# 1  12357.0  16831.0
# 2   6047.0   9715.0
# 3   3119.0   6066.0
# 4   5211.0   7139.0

# %%
New_Product.to_csv('./Files_Folder/New_Product_Details.csv', index = False)

# %%
train_data.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#   Product_Category_2 Product_Category_3  Purchase
# 0                 BB                 CC      8370
# 1                  6                 14     15200

# %%
# Creating a pivot Table from User & Product IDs
train_User_Prod = pd.pivot_table(train_data, values = 'Purchase', index = 'User_ID', columns = 'Product_ID')
train_User_Prod.head(2)
# Out:
# Product_ID  P00000142  P00000242  P00000342  P00000442  P00000542  P00000642  \
# User_ID
# 1000001       13650.0        NaN        NaN        NaN        NaN        NaN
# 1000002           NaN        NaN        NaN        NaN        NaN        NaN
#
# Product_ID  P00000742  P00000842  P00000942  P00001042  ...  P0098942  \
# User_ID                                                 ...
# 1000001           NaN        NaN        NaN        NaN  ...       NaN
# 1000002           NaN        NaN        NaN        NaN  ...       NaN
#
# Product_ID  P0099042  P0099142  P0099242  P0099342  P0099442  P0099642  \
# User_ID
# 1000001          NaN       NaN       NaN       NaN       NaN       NaN
# 1000002          NaN       NaN       NaN       NaN       NaN       NaN
#
# Product_ID  P0099742  P0099842  P0099942
# User_ID
# 1000001          NaN       NaN       NaN
# 1000002          NaN       NaN       NaN
#
# [2 rows x 3615 columns]

# %%
train_User_Prod.to_csv('./Files_Folder/tr_User_Prod_Original_Pivot.csv')

# %%
# The statistical description of each of the Product_ID
# The minimum and maximum for each Product_ID can be used for reversing the normalization step after prediction
tr_Us_Pr_statistics = train_User_Prod.describe()
tr_Us_Pr_statistics
# Out:
# Product_ID     P00000142     P00000242    P00000342    P00000442    P00000542  \
# count        1042.000000    344.000000   220.000000    80.000000   135.000000
# mean        11127.769674  10488.671512  5353.263636  4778.950000  5412.511111
# std          2305.016456   3188.308881  1844.410602  1649.117846  1689.678327
# min          2725.000000   3214.000000  1727.000000  1764.000000  1730.000000
# 25%         10593.000000   9559.500000  3727.500000  3599.750000  4448.000000
# 50%         10925.500000  10007.500000  5293.000000  5185.500000  5374.000000
# 75%         13370.750000  13023.000000  6928.750000  5384.750000  6943.500000
# max         13716.000000  16497.000000  8896.000000  8891.000000  8903.000000
#
# Product_ID     P00000642    P00000742     P00000842     P00000942  \
# count         455.000000   213.000000     31.000000     48.000000
# mean        14921.810989  6051.098592  10004.322581  10611.416667
# std          3626.883186  1617.500347   2878.013833   4411.512443
# min          3950.000000  1723.000000   3347.000000   4022.000000
# 25%         11900.000000  5235.000000   6756.500000   7926.250000
# 50%         15516.000000  5457.000000   9939.000000   9921.500000
# 75%         18991.500000  7066.000000  12919.000000  15283.000000
# max         19705.000000  8902.000000  13322.000000  19154.000000
#
# Product_ID     P00001042  ...      P0098942     P0099042     P0099142  \
# count         453.000000  ...     30.000000   135.000000     6.000000
# mean        13694.812362  ...   6917.866667  6188.933333  6018.666667
# std          3392.092634  ...   1677.481111  1728.052265  2075.220149
# min          3847.000000  ...   4071.000000  1738.000000  2319.000000
# 25%         11634.000000  ...   5883.250000  5314.500000  5840.000000
# 50%         15231.000000  ...   6951.000000  6908.000000  5995.500000
# 75%         15695.000000  ...   8053.000000  7099.500000  7486.750000
# max         19670.000000  ...  10001.000000  8882.000000  8030.000000
#
# Product_ID      P0099242     P0099342      P0099442      P0099642  \
# count         235.000000   394.000000    181.000000     13.000000
# mean         6778.174468  6986.515228  14298.375691   6439.230769
# std          2180.072511  1597.193797   3622.093836   2108.412442
# min          2012.000000  1803.000000   4093.000000   3903.000000
# 25%          5871.000000  5458.250000  12190.000000   4222.000000
# 50%          6179.000000  7041.000000  15998.000000   5972.000000
# 75%          8066.500000  8667.500000  16406.000000   7862.000000
# max         10076.000000  8906.000000  20684.000000  10056.000000
#
# Product_ID      P0099742     P0099842     P0099942
# count         115.000000   100.000000    10.000000
# mean         7929.956522  7269.550000  5148.400000
# std          2941.448874  1541.688051  2210.058431
# min          2670.000000  1912.000000  1791.000000
# 25%          5630.500000  6932.250000  4110.750000
# 50%          8185.000000  7129.000000  5294.500000
# 75%         10632.500000  8673.000000  6549.250000
# max         13661.000000  8891.000000  8833.000000
#
# [8 rows x 3615 columns]

# %%
# Saving the Train_User_Product_Statistics file as a csv
tr_Us_Pr_statistics.to_csv('./Files_Folder/train_User_Prod_stat.csv')

# %%
# Since all the counts add up to (90% of 500068), it imples that there is no product that was purchased 
# by two User_IDs.  
tr_Us_Pr_statistics.loc['count', :].sum()
# Out:
# 495062.0

# %%
# Normalizing the Purchases
minmax = preprocessing.MinMaxScaler(feature_range=(1,5))
train_User_Prod_Scaled = minmax.fit_transform(train_User_Prod)

# %%
train_User_Prod_Scaled
# Out:
# array([[4.97598035,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]])

# %%
x_row = list(train_User_Prod.index)
x_col = list(train_User_Prod.columns)
train_User_Prod_Scaled_df = pd.DataFrame(train_User_Prod_Scaled, index = x_row, columns = x_col)

# %%
train_User_Prod_Scaled_df.head(3)
# Out:
#          P00000142  P00000242  P00000342  P00000442  P00000542  P00000642  \
# 1000001    4.97598        NaN        NaN        NaN        NaN        NaN
# 1000002        NaN        NaN        NaN        NaN        NaN        NaN
# 1000003        NaN        NaN        NaN        NaN        NaN        NaN
#
#          P00000742  P00000842  P00000942  P00001042  ...  P0098942  P0099042  \
# 1000001        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 1000002        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 1000003        NaN        NaN        NaN        NaN  ...       NaN       NaN
#
#          P0099142  P0099242  P0099342  P0099442  P0099642  P0099742  P0099842  \
# 1000001       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1000002       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1000003       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#          P0099942
# 1000001       NaN
# 1000002       NaN
# 1000003       NaN
#
# [3 rows x 3615 columns]

# %%
train_User_Prod_Scaled_df.describe()
# Out:
#          P00000142   P00000242   P00000342  P00000442   P00000542   P00000642  \
# count  1042.000000  344.000000  220.000000  80.000000  135.000000  455.000000
# mean      4.058055    3.190671    3.023302   2.692129    3.053540    3.785607
# std       0.838874    0.960117    1.029103   0.925561    0.942244    0.920821
# min       1.000000    1.000000    1.000000   1.000000    1.000000    1.000000
# 25%       3.863434    2.910864    2.116195   2.030307    2.515684    3.018407
# 50%       3.984442    3.045773    2.989678   2.920303    3.032065    3.936465
# 75%       4.874352    3.953851    3.902357   3.032131    3.907291    4.818851
# max       5.000000    5.000000    5.000000   5.000000    5.000000    5.000000
#
#         P00000742  P00000842  P00000942   P00001042  ...   P0098942  \
# count  213.000000  31.000000  48.000000  453.000000  ...  30.000000
# mean     3.411533   3.669603   2.741850    3.489493  ...   2.920315
# std      0.901240   1.154091   1.166141    0.857509  ...   1.131522
# min      1.000000   1.000000   1.000000    1.000000  ...   1.000000
# 25%      2.956818   2.367218   2.032051    2.968527  ...   2.222428
# 50%      3.080513   3.643409   2.559477    3.877836  ...   2.942664
# 75%      3.977016   4.838396   3.976738    3.995134  ...   3.686003
# max      5.000000   5.000000   5.000000    5.000000  ...   5.000000
#
#          P0099042  P0099142    P0099242    P0099342    P0099442   P0099642  \
# count  135.000000  6.000000  235.000000  394.000000  181.000000  13.000000
# mean     3.492124  3.591257    3.364174    3.919057    3.460461   2.648777
# std      0.967554  1.453490    1.081385    0.899447    0.873267   1.370657
# min      1.000000  1.000000    1.000000    1.000000    1.000000   1.000000
# 25%      3.002520  3.466118    2.914187    3.058426    2.952143   1.207379
# 50%      3.894737  3.575031    3.066964    3.949740    3.870231   2.345035
# 75%      4.001960  4.619506    4.003224    4.865691    3.968597   3.573704
# max      5.000000  5.000000    5.000000    5.000000    5.000000   5.000000
#
#          P0099742    P0099842   P0099942
# count  115.000000  100.000000  10.000000
# mean     2.914278    4.070669   2.907072
# std      1.070494    0.883615   1.255358
# min      1.000000    1.000000   1.000000
# 25%      2.077427    3.877346   2.317665
# 50%      3.007097    3.990113   2.990060
# 75%      3.897825    4.875054   3.702783
# max      5.000000    5.000000   5.000000
#
# [8 rows x 3615 columns]

# %%
train_User_Prod_Scaled_df.head()
# Out:
#          P00000142  P00000242  P00000342  P00000442  P00000542  P00000642  \
# 1000001    4.97598        NaN        NaN        NaN        NaN        NaN
# 1000002        NaN        NaN        NaN        NaN        NaN        NaN
# 1000003        NaN        NaN        NaN        NaN        NaN        NaN
# 1000004        NaN        NaN        NaN        NaN        NaN        NaN
# 1000005        NaN        NaN        NaN        NaN        NaN        NaN
#
#          P00000742  P00000842  P00000942  P00001042  ...  P0098942  P0099042  \
# 1000001        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 1000002        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 1000003        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 1000004        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 1000005        NaN        NaN        NaN        NaN  ...       NaN       NaN
#
#          P0099142  P0099242  P0099342  P0099442  P0099642  P0099742  P0099842  \
# 1000001       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1000002       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1000003       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1000004       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1000005       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#          P0099942
# 1000001       NaN
# 1000002       NaN
# 1000003       NaN
# 1000004       NaN
# 1000005       NaN
#
# [5 rows x 3615 columns]

# %%
train_User_Prod.head()
# Out:
# Product_ID  P00000142  P00000242  P00000342  P00000442  P00000542  P00000642  \
# User_ID
# 1000001       13650.0        NaN        NaN        NaN        NaN        NaN
# 1000002           NaN        NaN        NaN        NaN        NaN        NaN
# 1000003           NaN        NaN        NaN        NaN        NaN        NaN
# 1000004           NaN        NaN        NaN        NaN        NaN        NaN
# 1000005           NaN        NaN        NaN        NaN        NaN        NaN
#
# Product_ID  P00000742  P00000842  P00000942  P00001042  ...  P0098942  \
# User_ID                                                 ...
# 1000001           NaN        NaN        NaN        NaN  ...       NaN
# 1000002           NaN        NaN        NaN        NaN  ...       NaN
# 1000003           NaN        NaN        NaN        NaN  ...       NaN
# 1000004           NaN        NaN        NaN        NaN  ...       NaN
# 1000005           NaN        NaN        NaN        NaN  ...       NaN
#
# Product_ID  P0099042  P0099142  P0099242  P0099342  P0099442  P0099642  \
# User_ID
# 1000001          NaN       NaN       NaN       NaN       NaN       NaN
# 1000002          NaN       NaN       NaN       NaN       NaN       NaN
# 1000003          NaN       NaN       NaN       NaN       NaN       NaN
# 1000004          NaN       NaN       NaN       NaN       NaN       NaN
# 1000005          NaN       NaN       NaN       NaN       NaN       NaN
#
# Product_ID  P0099742  P0099842  P0099942
# User_ID
# 1000001          NaN       NaN       NaN
# 1000002          NaN       NaN       NaN
# 1000003          NaN       NaN       NaN
# 1000004          NaN       NaN       NaN
# 1000005          NaN       NaN       NaN
#
# [5 rows x 3615 columns]

# %%
train_User_Prod_Scaled_df.to_csv('./Files_Folder/tr_User_Prod_Normalized_Pivot.csv')

# %%
# Preparing Data in the form acceptable by Surprise Package

# %%
train_data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#   Product_Category_2 Product_Category_3  Purchase
# 0                 BB                 CC      8370
# 1                  6                 14     15200
# 2                 BB                 CC      1422
# 3                 14                 CC      1057
# 4                 BB                 CC      7969

# %%
User_ID_list = list(train_data.User_ID)
Prod_ID_list = list(train_data.Product_ID)

# %%
# Creating a list of normalized purchases in the same order as listed in the train data set
Purc_list = []
for i in range(len(User_ID_list)):
    Purc_list.append(train_User_Prod_Scaled_df.loc[User_ID_list[i], Prod_ID_list[i]])

# %%
User_Prod_NormPurc = {'User_ID': User_ID_list, 'Product_ID': Prod_ID_list, 'Normalized_Purchase': Purc_list}

# %%
User_Prod_NormPurc_df = pd.DataFrame(User_Prod_NormPurc)

# %%
User_Prod_NormPurc_df.head()
# Out:
#    User_ID Product_ID  Normalized_Purchase
# 0  1000001  P00069042             3.067944
# 1  1000001  P00248942             3.857687
# 2  1000001  P00087842             4.011863
# 3  1000001  P00085442             2.958953
# 4  1000002  P00285442             3.636497

# %%
User_Prod_NormPurc_df.describe()
# Out:
#             User_ID  Normalized_Purchase
# count  4.950620e+05        495062.000000
# mean   1.003027e+06             3.538755
# std    1.727099e+03             1.082961
# min    1.000001e+06             1.000000
# 25%    1.001514e+06             2.955803
# 50%    1.003075e+06             3.887335
# 75%    1.004473e+06             4.035739
# max    1.006040e+06             5.000000

# %%
User_Prod_NormPurc_df.to_csv('./Files_Folder/User_Prod_NormPurc.csv', index=False)
